# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# load and investigate the data here:
df = pd.read_csv('tennis_stats.csv')
df.head()
# Out:
#                  Player  Year  FirstServe  FirstServePointsWon  \
# 0           Pedro Sousa  2016        0.88                 0.50
# 1       Roman Safiullin  2017        0.84                 0.62
# 2           Pedro Sousa  2017        0.83                 0.60
# 3   Rogerio Dutra Silva  2010        0.83                 0.64
# 4  Daniel Gimeno-Traver  2017        0.81                 0.54
#
#    FirstServeReturnPointsWon  SecondServePointsWon  \
# 0                       0.38                  0.50
# 1                       0.26                  0.33
# 2                       0.28                  0.53
# 3                       0.34                  0.59
# 4                       0.00                  0.33
#
#    SecondServeReturnPointsWon  Aces  BreakPointsConverted  BreakPointsFaced  \
# 0                        0.39     0                  0.14                 7
# 1                        0.07     7                  0.00                 7
# ...

# %%
# perform exploratory analysis here:
plt.scatter(df.Aces, df.Wins)
plt.show()
plt.scatter(df.BreakPointsOpportunities, df.Winnings)
plt.show()
plt.scatter(df.DoubleFaults, df.Losses)
plt.show()

# %% [markdown]
# ### Perform single feature linear regressions here

# %%
## Double faults vs Losses 
doubleFaults = df[['DoubleFaults']]
losses = df[['Losses']]

x_train, x_test, y_train, y_test = train_test_split(doubleFaults, losses, \
                                                    train_size=0.8, test_size=0.2)

# create and fit model
model = LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))

losses_predict = model.predict(x_test)
plt.scatter(y_test, losses_predict, alpha = 0.4)
# Out:
# 0.7716374754888145

# %%
## BreakPointsSaved vs Ranking 
BreakPointsSaved = df[['BreakPointsSaved']]
Ranking = df[['Ranking']]

x_train, x_test, y_train, y_test = train_test_split(BreakPointsSaved, Ranking, \
                                                    train_size=0.8, test_size=0.2)

# create and fit model
model = LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))

ranking_predict = model.predict(x_test)
plt.scatter(y_test, ranking_predict, alpha = 0.4)
# Out:
# 0.019684454100232673

# %%
## FirstServePointsWon vs Wins 
FirstServePointsWon = df[['FirstServePointsWon']]
Wins = df[['Wins']]

x_train, x_test, y_train, y_test = train_test_split(FirstServePointsWon, Wins, \
                                                    train_size=0.8, test_size=0.2)

# create and fit model
model = LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))

Wins_predict = model.predict(x_test)
plt.scatter(y_test, Wins_predict, alpha = 0.4)
# Out:
# 0.13278353719495584

# %%
## BreakPointsOpportunities vs Winnings 
BreakPointsOpportunities = df[['BreakPointsOpportunities']]
Winnings = df[['Winnings']]

x_train, x_test, y_train, y_test = train_test_split(BreakPointsOpportunities, Winnings, \
                                                    train_size=0.8, test_size=0.2)

# create and fit model
model = LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))

Winnings_predict = model.predict(x_test)
plt.scatter(y_test, Winnings_predict, alpha = 0.4)
# Out:
# 0.7784467509069914

# %% [markdown]
# ### Perform two feature linear regressions here:

# %%
## DoubleFaults, ReturnGamesPlayed vs Losses 
features = df[['DoubleFaults', 'ReturnGamesPlayed']]
outcome = df[['Losses']]

x_train, x_test, y_train, y_test = train_test_split(features, outcome, \
                                                    train_size=0.8, test_size=0.2)

# create and fit model
model = LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))

outcome_predict = model.predict(x_test)
plt.scatter(y_test, outcome_predict, alpha = 0.4)
# Out:
# 0.8923429745434787

# %%
## BreakPointsOpportunities, FirstServeReturnPointsWon vs Winnings 
features = df[['BreakPointsOpportunities', 'FirstServeReturnPointsWon']]
outcome = df[['Winnings']]

x_train, x_test, y_train, y_test = train_test_split(features, outcome, \
                                                    train_size=0.8, test_size=0.2)

# create and fit model
model = LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))

outcome_predict = model.predict(x_test)
plt.scatter(y_test, outcome_predict, alpha = 0.4)
# Out:
# 0.7820839708980566

# %% [markdown]
# ### Perform multiple feature linear regressions here:
